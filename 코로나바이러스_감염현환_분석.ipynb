# %% [markdown]
# <a href="https://colab.research.google.com/github/MATHKIMS/dongwoo_project/blob/main/%EC%BD%94%EB%A1%9C%EB%82%98%EB%B0%94%EC%9D%B4%EB%9F%AC%EC%8A%A4_%EA%B0%90%EC%97%BC%ED%98%84%ED%99%98_%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 데이터 분석 목표
#
# 대한민국 코로나 바이러스 감염 현황을 분석하는 프로젝트를 진행하면서, 데이터 분석의 기본 프로세스를 이해한다.
#
# 다양한 데이터의 출러를 알고\, 효과적인 데이터를 선택할 수 있다.
#
# 기초적인 데이터의 정제 및 가공법을 수행할 수 있다.
#
# 데이터를 시각화 하여 의미있는 정보로 통찰을 얻는 방법을 경험한다.
#
# 원하는 기능을 찾는 검색 방법을 습득할 수 있다.

# %% [markdown]
# # 1. 프로젝트 개요

# %% [markdown]
# ## (1) 프로젝트의 목적
# 2022년  상반기 변이바이러스 오미크론이 기승을 부리면서 많은 코로나 확진자가 양산되고 있다.
#
# 코로나 감염현황에 대한 데이터가 있고 원하는 형태로 그래프를 그려서 확인해보자.

# %% [markdown]
# ## (2) 문제 정의
#
# 안나의 고민
# 저는 미국에서 살고 있는 안나입니다..(중략)
# 이번 방학때 한국의 친한 친구인 철수를 초대하고 싶은데 미국의 코로나 상황이 안좋으면 친구를 초대하지 못 할 것 같습니다.
# 현재 미국의 코로나 상황이 대한민국보다 더 나을끼요?

# %% [markdown]
# 미국과 한국의 코로나 상황을 비교하는 문제!

# %% [markdown]
# ##(3) 프로젝트의 기대결과
#
# 대한민국과 하와이의 총 인구가 다르기때문에 확진자 수를 단순 비교하는 것은 바람직하지 못하다.
#
# 일자별 총 인구 대비 확진자 수 비율의 변화 추이를 보는것이 의미가 있을것이다.

# %% [markdown]
# # 2. 데이터 수집

# %% [markdown]
# 적절한 데이터
#
# 포괄성 : 필요한 데이터가 있는가?
#
# 최신성 : 최신데이터를 포함하는가?
#
# 정확성 : 정확한 데이터 인가?
#
# 일관성 : 데이터의 형태가 일관적인가?
#
# 신뢰성 : 왜곡이 없고 신뢰할수 있는가?
#
# 사용성: 사용하기 편한가?

# %% [markdown]
# 프로젝트에는 어떤 데이터가 필요할까?
#
# 각 지역의 총 인구
# 최신정보를 가진 각 지역의 일자별 코로나 확진자 수

# %% [markdown]
# 데이터 검색

# %%
# https://ourworldindata.org/explorers/coronavirus-data-explorer

# %%
import pandas as pd

pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 2e218d10984e9919f0296931d92ea851c6a6faf5
# python           : 3.9.16.final.0
# python-bits      : 64
# OS               : Linux
# OS-release       : 5.10.147+
# Version          : #1 SMP Sat Dec 10 16:00:40 UTC 2022
# machine          : x86_64
# processor        : x86_64
# byteorder        : little
# LC_ALL           : None
# LANG             : en_US.UTF-8
# LOCALE           : en_US.UTF-8
#
# pandas           : 1.5.3
# numpy            : 1.22.4
# pytz             : 2022.7.1
# dateutil         : 2.8.2
# setuptools       : 67.7.2
# pip              : 23.0.1
# Cython           : 0.29.34
# pytest           : 7.2.2
# hypothesis       : None
# sphinx           : 3.5.4
# blosc            : None
# feather          : None
# xlsxwriter       : None
# lxml.etree       : 4.9.2
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : 2.9.6
# jinja2           : 3.1.2
# IPython          : 7.34.0
# pandas_datareader: 0.10.0
# ...

# %%
raw_df=pd.read_csv(r'/content/drive/MyDrive/한남대 학부/2023학년도/파이썬데이터분석/data/owid-covid-data.csv',encoding='cp949')
raw_df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1           AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2           AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3           AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4           AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
# ...         ...       ...          ...         ...          ...        ...
# 304519      ZWE    Africa     Zimbabwe  2023-04-15     264607.0       10.0
# 304520      ZWE    Africa     Zimbabwe  2023-04-16     264610.0        3.0
# 304521      ZWE    Africa     Zimbabwe  2023-04-17     264613.0        3.0
# 304522      ZWE    Africa     Zimbabwe  2023-04-18     264613.0        0.0
# 304523      ZWE    Africa     Zimbabwe  2023-04-19     264613.0        0.0
#
# ...

# %%
# raw data 데이터프레임 정보확인
raw_df.info()
#66개의 피처가 있음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304524 entries, 0 to 304523
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    304524 non-null  object
#  1   continent                                   290038 non-null  object
#  2   location                                    304524 non-null  object
#  3   date                                        304524 non-null  object
#  4   total_cases                                 268489 non-null  float64
#  5   new_cases                                   295743 non-null  float64
#  6   new_cases_smoothed                          294479 non-null  float64
#  7   total_deaths                                247931 non-null  float64
#  8   new_deaths                                  295839 non-null  float64
# ...

# %% [markdown]
# ## 데이터 가공하기

# %%
raw_df.head() # 상위 5개 레코드 확인
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
# 원하는 열만 추려내기

selected_columns=['iso_code','location','date','total_cases','population']

revised_df=raw_df[selected_columns] #df[[컬럼리스트]]
revised_df
# Out:
#        iso_code     location        date  total_cases  population
# 0           AFG  Afghanistan  2020-01-03          NaN  41128772.0
# 1           AFG  Afghanistan  2020-01-04          NaN  41128772.0
# 2           AFG  Afghanistan  2020-01-05          NaN  41128772.0
# 3           AFG  Afghanistan  2020-01-06          NaN  41128772.0
# 4           AFG  Afghanistan  2020-01-07          NaN  41128772.0
# ...         ...          ...         ...          ...         ...
# 304519      ZWE     Zimbabwe  2023-04-15     264607.0  16320539.0
# 304520      ZWE     Zimbabwe  2023-04-16     264610.0  16320539.0
# 304521      ZWE     Zimbabwe  2023-04-17     264613.0  16320539.0
# 304522      ZWE     Zimbabwe  2023-04-18     264613.0  16320539.0
# 304523      ZWE     Zimbabwe  2023-04-19     264613.0  16320539.0
#
# [304524 rows x 5 columns]

# %%
locations=revised_df['location']

# %%
locations.unique() # unique 메서드는 ndarray 로 반환 판다스에서 시리즈는 ndarray이다.
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
kor_df=revised_df[revised_df.location=='South Korea']

kor_date_index_df=kor_df.set_index('date') #인덱스 변경하기
kor_date_index_df.head()
# Out:
#            iso_code     location  total_cases  population
# date
# 2020-01-03      KOR  South Korea          NaN  51815808.0
# 2020-01-04      KOR  South Korea          NaN  51815808.0
# 2020-01-05      KOR  South Korea          NaN  51815808.0
# 2020-01-06      KOR  South Korea          NaN  51815808.0
# 2020-01-07      KOR  South Korea          NaN  51815808.0

# %%
usa_df=revised_df[revised_df.location=='United States']
usa_df

usa_date_index_df=usa_df.set_index('date') #인덱스 변경하기
usa_date_index_df.head()
# Out:
#            iso_code       location  total_cases   population
# date
# 2020-01-03      USA  United States          NaN  338289856.0
# 2020-01-04      USA  United States          NaN  338289856.0
# 2020-01-05      USA  United States          NaN  338289856.0
# 2020-01-06      USA  United States          NaN  338289856.0
# 2020-01-07      USA  United States          NaN  338289856.0

# %% [markdown]
# # 4. 데이터 시각화

# %%
kor_total_cases=kor_date_index_df['total_cases'].dropna()
kor_total_cases.drop(kor_total_cases.index[0], inplace=True)
kor_total_cases
# Out:
# date
# 2020-01-20           1.0
# 2020-01-21           1.0
# 2020-01-22           1.0
# 2020-01-23           1.0
# 2020-01-24           2.0
#                  ...
# 2023-04-15    30978954.0
# 2023-04-16    30989142.0
# 2023-04-17    30994088.0
# 2023-04-18    30994088.0
# 2023-04-19    30994088.0
# Name: total_cases, Length: 1186, dtype: float64

# %%
usa_total_cases=usa_date_index_df['total_cases'].dropna()
usa_total_cases
# Out:
# date
# 2020-01-20            1.0
# 2020-01-21            1.0
# 2020-01-22            1.0
# 2020-01-23            1.0
# 2020-01-24            1.0
#                  ...
# 2023-04-15    102977396.0
# 2023-04-16    102977396.0
# 2023-04-17    102977396.0
# 2023-04-18    102977396.0
# 2023-04-19    102977396.0
# Name: total_cases, Length: 1186, dtype: float64

# %%
final_df=pd.DataFrame(dic)
final_df
# Out:
#                    KOR          USA
# date
# 2020-01-20         1.0          1.0
# 2020-01-21         1.0          1.0
# 2020-01-22         1.0          1.0
# 2020-01-23         1.0          1.0
# 2020-01-24         2.0          1.0
# ...                ...          ...
# 2023-04-15  30978954.0  102977396.0
# 2023-04-16  30989142.0  102977396.0
# 2023-04-17  30994088.0  102977396.0
# 2023-04-18  30994088.0  102977396.0
# 2023-04-19  30994088.0  102977396.0
#
# [1186 rows x 2 columns]

# %%
# 선그래프 실제 확진자수
final_df.plot.line()
# Out:
# <Axes: xlabel='date'>

# %%
#올해 그래프
final_df['2022-01-01':].plot.line()
# Out:
# <Axes: xlabel='date'>

# %%
final_df['2022-01-01':].plot.line(rot=45)
# Out:
# <Axes: xlabel='date'>

# %%
#대한민국 인구
kor_population=kor_date_index_df['population']['2022-01-22']
usa_population=usa_date_index_df['population']['2022-01-22']
print('미국 인구(',usa_population,')/ 대한민국 인구(',kor_population,')')
# Out:
# 미국 인구( 338289856.0 )/ 대한민국 인구( 51815808.0 )

# %%
#인구 비율 구하기
rate=round((usa_population)/(kor_population),2)
rate
# Out:
# 6.53

# %%
#확진자 비율을 적용한 최종 데이터프레임 생성하기
final_revised_df=pd.DataFrame({
    'KOR':kor_total_cases*rate,
    'USA':usa_total_cases
})

final_revised_df.head()
# Out:
#               KOR  USA
# date
# 2020-01-20   6.53  1.0
# 2020-01-21   6.53  1.0
# 2020-01-22   6.53  1.0
# 2020-01-23   6.53  1.0
# 2020-01-24  13.06  1.0

# %%
final_revised_df[:].plot.line(rot=45)
# Out:
# <Axes: xlabel='date'>

# %%
final_revised_df['2022-01-01':].plot.line(rot=45)
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# 결론
# 대한민국보다 미국의 코로나 확진 비율이 더 낮으므로 안나는 친구를 초대하는 것은 긍정적이다.
